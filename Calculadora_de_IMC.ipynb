# %%
def calculadora_imc():
  print('=' * 40)
  print("Bem vindo à calculadora de IMC.")
  print("=" * 40)
  historico = [] #Lista para armazenar a história de cálculos
  while True:
      # Entrada de dados com validação
    nome = input('Digite seu nome: ').strip().title()
    try:
      peso = float(input(f"{nome}, digite seu peso em kg: "))
      altura = float(input(f"{nome}, digite sua altura em metros: "))
      if peso <=0 or altura <= 0:
        print("Peso e altura devem ser maiores que 0. Tente novamente!")
        continue
    except ValueError:
      print("Entrada inválida! Por favor, digite números válidos.")
      continue

      # Cálculo do IMC
    imc = peso / (altura ** 2)

      # Classificação do IMC
    if imc < 18.5:
     classificacao = "Abaixo do peso."
     recomendacao = "Tente manter uma alimentação balanceada e procure orientação médica."
    elif 18.5 <= imc < 24.9:
     classificacao = "Peso normal."
     recomendacao = "Parabéns! Continue mantendo uma vida saudável."
    elif 25 <= imc < 29.9:
     classificacao = "Sobrepeso"
     recomendacao = "Considere praticar atividade física regularmente e revisar sua alimentação."
    else:
     classificacao = "Obesidade"
     recomendacao = "É importante procurar atendimento médico para melhorar a sua saúde."

    # Exibindo resultados
  print("\n" + "-" * 40)
  print(f"{nome}, o seu IMC é: {imc:.2f}")
  print(f"Classificação: {classificacao}")
  print(f"Recomendação: {recomendacao}")
  print("-" * 40)

  # Salvando no histórico
  historico.append((nome, peso, altura, imc, classificacao))

  # Perguntar se deseja continuar
  continuar = input("\nDeseja calcular o IMC de outra pessoa? (s/n): ").strip().lower()
  if continuar != "s":
    print("\n" + "=" * 40)
    print("Histórico de Cálculos: ")
    for i, (nome, peso, altura, imc, classificacao) in enumerate(historico, start=1):
      print(f"{i}. Nome: {nome}, Peso: {peso}kg, Altura: {altura}m, IMC: {imc:.2f}, Classificação: {classificacao}")

def calculadora_imc():
  print('=' * 40)
  print("Bem vindo à calculadora de IMC.")
  print("=" * 40)
  historico = [] #Lista para armazenar a história de cálculos
  while True:
      # Entrada de dados com validação
    nome = input('Digite seu nome: ').strip().title()
    try:
      peso = float(input(f"{nome}, digite seu peso em kg: "))
      altura = float(input(f"{nome}, digite sua altura em metros: "))
      if peso <=0 or altura <= 0:
        print("Peso e altura devem ser maiores que 0. Tente novamente!")
        continue
    except ValueError:
      print("Entrada inválida! Por favor, digite números válidos.")
      continue

      # Cálculo do IMC
    imc = peso / (altura ** 2)

      # Classificação do IMC
    if imc < 18.5:
     classificacao = "Abaixo do peso."
     recomendacao = "Tente manter uma alimentação balanceada e procure orientação médica."
    elif 18.5 <= imc < 24.9:
     classificacao = "Peso normal."
     recomendacao = "Parabéns! Continue mantendo uma vida saudável."
    elif 25 <= imc < 29.9:
     classificacao = "Sobrepeso"
     recomendacao = "Considere praticar atividade física regularmente e revisar sua alimentação."
    else:
     classificacao = "Obesidade"
     recomendacao = "É importante procurar atendimento médico para melhorar a sua saúde."

    # Exibindo resultados
    print("\n" + "-" * 40)
    print(f"{nome}, o seu IMC é: {imc:.2f}.")
    print(f"Classificação: {classificacao}.")
    print(f"Recomendação: {recomendacao}")
    print ("-" * 40)

    # Salvando no histórico
    historico.append((nome, peso, altura, imc, classificacao))

    # Perguntar se deseja continuar
    continuar = input("\nDeseja calcular o IMC de outra pessoa? (s/n): ").strip().lower()
    if continuar != "s":
      print("\n" + "=" * 40)
      print("Histórico de Cálculos: ")
      for i, (nome, peso, altura, imc, classificacao) in enumerate(historico, start=1):
        print(f"{i}. Nome: {nome}, Peso: {peso}kg, Altura: {altura}m, IMC: {imc:.2f}, Classificação: {classificacao}")
      print("=" * 40)
      print("Obrigada por usar a calculadora de IMC!Até mais!")
      break

    # Executar a função
calculadora_imc()
# Out:
# ...
# Bem vindo à calculadora de IMC.
# ...
# Digite seu nome: Ana
# Ana, digite seu peso em kg: 70
# Ana, digite sua altura em metros: 1.50
#
# ----------------------------------------
# Ana, o seu IMC é: 31.11
# Classificação: Obesidade
# Recomendação: É importante procurar atendimento médico para melhorar a sua saúde.
# ----------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-eb71f8db6beb> in <cell line: 0>()
#     109
#     110     # Executar a função
# --> 111 calculadora_imc()
#
# <ipython-input-11-eb71f8db6beb> in calculadora_imc()
#      98
#      99     # Perguntar se deseja continuar
# --> 100     continuar = input("\nDeseja calcular o IMC de outra pessoa? (s/n): ").strip().lower()
#     101     if continuar != "s":
#     102       print("\n" + "=" * 40)
#
# ...
